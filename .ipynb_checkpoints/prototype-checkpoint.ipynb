# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/Users/hari/Downloads/Maternal Health Risk Data Set.csv.xls')
df
# Out:
#       Age  SystolicBP  DiastolicBP    BS  BodyTemp  HeartRate  RiskLevel
# 0      25         130           80  15.0      98.0         86  high risk
# 1      35         140           90  13.0      98.0         70  high risk
# 2      29          90           70   8.0     100.0         80  high risk
# 3      30         140           85   7.0      98.0         70  high risk
# 4      35         120           60   6.1      98.0         76   low risk
# ...   ...         ...          ...   ...       ...        ...        ...
# 1009   22         120           60  15.0      98.0         80  high risk
# 1010   55         120           90  18.0      98.0         60  high risk
# 1011   35          85           60  19.0      98.0         86  high risk
# 1012   43         120           90  18.0      98.0         70  high risk
# 1013   32         120           65   6.0     101.0         76   mid risk
#
# [1014 rows x 7 columns]

# %%
data = df.dropna()

# %%
data
# Out:
#       Age  SystolicBP  DiastolicBP    BS  BodyTemp  HeartRate  RiskLevel
# 0      25         130           80  15.0      98.0         86  high risk
# 1      35         140           90  13.0      98.0         70  high risk
# 2      29          90           70   8.0     100.0         80  high risk
# 3      30         140           85   7.0      98.0         70  high risk
# 4      35         120           60   6.1      98.0         76   low risk
# ...   ...         ...          ...   ...       ...        ...        ...
# 1009   22         120           60  15.0      98.0         80  high risk
# 1010   55         120           90  18.0      98.0         60  high risk
# 1011   35          85           60  19.0      98.0         86  high risk
# 1012   43         120           90  18.0      98.0         70  high risk
# 1013   32         120           65   6.0     101.0         76   mid risk
#
# [1014 rows x 7 columns]

# %%
age_RiskLevel = data.groupby(['Age','RiskLevel']).size().unstack(fill_value=0)
age_RiskLevel.plot(kind='bar',stacked=True,figsize = [10,6],color = ['green','orange','red'])
plt.xlabel('Age')
plt.ylabel('Count')
plt.title('Age vs RiskLevel')
plt.legend(title='Risk Level', labels=['Low', 'Medium', 'High'])
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
sysBP_RiskLevel = data.groupby(['SystolicBP', 'RiskLevel']).size().unstack(fill_value=0)
sysBP_RiskLevel.plot(kind='bar',stacked =True,figsize=[10,6],color=['green','orange','red'])
plt.xlabel('SystolicBP')
plt.ylabel('Count')
plt.title('SystolicBP vs RiskLevel')
plt.legend(title='Risk Level', labels=['Low', 'Medium', 'High'])
plt.xticks(rotation= 45)
plt.tight_layout()
plt.show()

# %%
Temp_RiskLevel = data.groupby(['BodyTemp','RiskLevel']).size().unstack(fill_value=0)
HeartRate_RiskLevel.plot(kind = 'bar',stacked = True,figsize=[10,6],color=['green','orange','red'])
plt.xlabel('Temperature')
plt.ylabel('Count')
plt.title('HeartRate vs RiskLevel')
plt.legend(title='Risk Level', labels=['Low', 'Medium', 'High'])
plt.xticks(rotation= 45)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 Temp_RiskLevel = data.groupby(['BodyTemp','RiskLevel']).size().unstack(fill_value=0)
# ----> 2 HeartRate_RiskLevel.plot(kind = 'bar',stacked = True,figsize=[10,6],color=['green','orange','red'])
#       3 plt.xlabel('Temperature')
#       4 plt.ylabel('Count')
#
# NameError: name 'HeartRate_RiskLevel' is not defined

# %%
HeartRate_RiskLevel = data.groupby(['HeartRate','RiskLevel']).size().unstack(fill_value=0)
HeartRate_RiskLevel.plot(kind = 'bar',stacked = True,figsize=[10,6],color=['green','orange','red'])
plt.xlabel('HeartRate')
plt.ylabel('Count')
plt.title('HeartRate vs RiskLevel')
plt.legend(title='Risk Level', labels=['Low', 'Medium', 'High'])
plt.xticks(rotation= 45)
plt.tight_layout()
plt.show()

# %%
DiastolicBP_RiskLevel = data.groupby(['DiastolicBP','RiskLevel']).size().unstack(fill_value=0)
DiastolicBP_RiskLevel.plot(kind='bar',stacked=True,figsize=[10,6],color=["green",'orange','red'])
plt.xlabel('Diastolic BP')
plt.ylabel('Count')
plt.title("Diastolic BP vs RiskLevel")
plt.show()

# %%
Bs_Risklevel = data.groupby(['BS','RiskLevel']).size().unstack(fill_value=0)
Bs_Risklevel.plot(kind='bar',stacked =True,figsize=[10,6],color=['green','orange','red'])
plt.xlabel('BS')
plt.ylabel('Count')
plt.title('BS vs Risk Level')
plt.show()

# %%
risk_level_map = {'high risk':2,'mid risk':1,'low risk':0}
data['RiskLevel'] = data['RiskLevel'].map(risk_level_map)

# %%
data
# Out:
#       Age  SystolicBP  DiastolicBP    BS  BodyTemp  HeartRate  RiskLevel
# 0      25         130           80  15.0      98.0         86          2
# 1      35         140           90  13.0      98.0         70          2
# 2      29          90           70   8.0     100.0         80          2
# 3      30         140           85   7.0      98.0         70          2
# 4      35         120           60   6.1      98.0         76          0
# ...   ...         ...          ...   ...       ...        ...        ...
# 1009   22         120           60  15.0      98.0         80          2
# 1010   55         120           90  18.0      98.0         60          2
# 1011   35          85           60  19.0      98.0         86          2
# 1012   43         120           90  18.0      98.0         70          2
# 1013   32         120           65   6.0     101.0         76          1
#
# [1014 rows x 7 columns]

# %% [markdown]
# # MODEL BUILD

# %% [markdown]
# As we can see from the graphs most of the parameters  are important in finding the risk level in the below we will first divide the data as TEST,TRAIN and VAL and use different algorithms to find the best and use it

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
train_data, temp = train_test_split(data,random_state=42,test_size=0.2)

# %%
val_data,test_data = train_test_split(temp,random_state=42,test_size=0.5)

# %%
train_data
# Out:
#      Age  SystolicBP  DiastolicBP    BS  BodyTemp  HeartRate  RiskLevel
# 847   30         120           80   9.0     101.0         76          1
# 332   23         130           70   6.9      98.0         70          1
# 707   32         120           90   6.9      98.0         70          1
# 218   31         120           60   6.1      98.0         76          1
# 425   35         100           60  15.0      98.0         80          2
# ..   ...         ...          ...   ...       ...        ...        ...
# 106   50         140           90  15.0      98.0         90          2
# 270   22         120           90   7.0      98.0         82          0
# 860   17          90           63   6.9     101.0         70          1
# 435   65         130           80  15.0      98.0         86          2
# 102   48         140           90  15.0      98.0         90          2
#
# [811 rows x 7 columns]

# %%
val_data
# Out:
#      Age  SystolicBP  DiastolicBP    BS  BodyTemp  HeartRate  RiskLevel
# 59    15          76           49   6.4      98.0         77          0
# 88    19         120           75   6.9      98.0         66          1
# 900   60          90           65   7.9      98.0         77          0
# 208   25         120           80   7.0      98.0         66          0
# 120   48         120           80  11.0      98.0         88          2
# ..   ...         ...          ...   ...       ...        ...        ...
# 886   15          76           49   6.8      98.0         77          0
# 740   29         130           70   6.1      98.0         78          1
# 536   16         100           70   7.5      98.0         80          0
# 832   60         120           80   7.5      98.0         75          1
# 883   35         120           60   6.1      98.0         76          0
#
# [101 rows x 7 columns]

# %%
test_data
# Out:
#      Age  SystolicBP  DiastolicBP    BS  BodyTemp  HeartRate  RiskLevel
# 405   55         120           90   6.8      98.0         66          1
# 588   12          90           60   7.5     102.0         66          1
# 184   60         120           80   6.1      98.0         75          0
# 689   40         160          100  19.0      98.0         77          2
# 444   43         130           80  18.0      98.0         70          1
# ..   ...         ...          ...   ...       ...        ...        ...
# 168   22         100           65   7.2      98.0         70          0
# 841   39         110           70   7.9      98.0         80          1
# 213   60          90           65   7.0      98.0         77          0
# 634   30          90           65   8.0      98.0         77          1
# 914   17         120           80   7.5     102.0         76          0
#
# [102 rows x 7 columns]

# %%
X = train_data.drop(columns=['RiskLevel'])
y = train_data['RiskLevel']

# %%
model = DecisionTreeRegressor(random_state=42)
model.fit(X,y)
# Out:
# DecisionTreeRegressor(random_state=42)

# %%
X_test = test_data.drop(columns=['RiskLevel'])
y_test = test_data['RiskLevel']

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
mse = mean_squared_error(y_test,y_pred)
r2_score = r2_score(y_test,y_pred)

print(f"Mean Squared Error MSE: {mse}")
print(f"R2 score: {r2_score}")
# Out:
# Mean Squared Error MSE: 0.3103838762052303
# R2 score: 0.4941676303196717

# %% [markdown]
# ## Graphical Representation of Graph

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 8))
plot_tree(model, feature_names=X.columns, filled=True, rounded=True)
plt.show()

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

# %%
from sklearn.preprocessing import StandardScaler

# %%
X_val = val_data.drop(columns=['RiskLevel'])
y_val = val_data['RiskLevel']

# %%
scaler = StandardScaler()
X = scaler.fit_transform(X)
X_val = scaler.fit_transform(X_val)
X_test = scaler.fit_transform(X_test)

# %%
log_reg = LogisticRegression(multi_class='multinomial',
                             random_state=42,
                             solver='lbfgs',
                             max_iter=1000)
log_reg.fit(X,y)

y_val_pred = log_reg.predict(X_val)
accuracy = accuracy_score(y_val,y_val_pred)
classification_rep = classification_report(y_val,y_val_pred)
print(f"accuracy: {accuracy}")
print(f"Classification Report : {classification_rep}")
# Out:
# accuracy: 0.594059405940594
# Classification Report :               precision    recall  f1-score   support
#
#            0       0.61      0.81      0.69        42
#            1       0.50      0.26      0.34        38
#            2       0.64      0.76      0.70        21
#
#     accuracy                           0.59       101
#    macro avg       0.58      0.61      0.58       101
# weighted avg       0.57      0.59      0.56       101
# /Users/hari/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {'C':[0.01,0.1,1,10,100],
              'solver' : ['lbfgs','saga']
}

grid_search = GridSearchCV(LogisticRegression(
                           max_iter = 1000, 
                           random_state = 42),
                           param_grid,
                           cv=5,
                           scoring='accuracy',
                          verbose=1)
grid_search.fit(X,y)
print("Best Parameters",grid_search.best_params_)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Best Parameters {'C': 0.01, 'solver': 'lbfgs'}

# %%
from sklearn.linear_model import SGDClassifier

# %%
sgd_clf = SGDClassifier(max_iter=1000,random_state=42,loss='log_loss')
sgd_clf.fit(X,y)


y_test_pred = sgd_clf.predict(X_test)
accuracy = accuracy_score(y_test,y_test_pred)
print(f"accuracy: {accuracy}")
# Out:
# accuracy: 0.5980392156862745

# %%
from xgboost import XGBClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
#Random Forest
rf = RandomForestClassifier(random_state=42)
rf.fit(X, y)
print("Test Accuracy:", rf.score(X_test, y_test))
# Out:
# Test Accuracy: 0.7549019607843137

# %%
#XGboost
xgb = XGBClassifier(random_state = 42)
xgb.fit(X,y)
print("Test Accuracy:",xgb.score(X_test,y_test))
# Out:
# Test Accuracy: 0.7450980392156863

# %%
from sklearn.model_selection import cross_val_score

# %%
cv_scores = cross_val_score(rf,X,y,cv=5,scoring='accuracy')
print("cross Validation accuracy: ", cv_scores.mean())
# Out:
# cross Validation accuracy:  0.8237067333181851

# %%
cv_scores = cross_val_score(rf,X_val,y_val,cv=5,scoring='accuracy')
print("cross Validation accuracy: ", cv_scores.mean())
# Out:
# cross Validation accuracy:  0.6223809523809524
